# %% [markdown]
# # Uploading your data to GitHub
#
# ## Option 1: Mount Drive
#
# Notes:
# * Students need to have data in the same location as you!
# * Good for when students are doing independent projects; not all working on the same data.
#
# To do, students can click the **Mount Drive** button on the left hand side, or they can run the cell below:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Option 2: Upload to Colab
#
# Short video for students here:
# [link text](https://www.loom.com/share/830c178cc78447b68156cd8ff1423fb3?t=15)

# %% [markdown]
# ## Option 3: Use URL from GitHub

# %%
import pandas as pd

# URL from GitHub (copied directly from bar in browser)
original_URL = 'https://github.com/AllenInstitute/EducationAndEngagement/blob/main/NeuroCodingWorkshop/support_files/datasets/species_brainmass_neurons.csv'
raw_url = original_URL.replace("github.com", "raw.githubusercontent.com")

filepath = raw_url.replace("/blob/", "/")
# Out:
#                  Species         Order  cortex_mass_g   Neurons  Other_cells  \
# 0           Sorex fumeus  Eulipotyphla          0.084   9730000      9290000
# 1           Mus musculus        Glires          0.173  13688162     12061838
# 2     Blarina brevicauda  Eulipotyphla          0.197  11876000     15820000
# 3  Heterocephalus glaber        Glires          0.184   6151875      8398125
# 4     Condylura cristata  Eulipotyphla          0.420  17250000     32010000
#
#    Neurons_mg  Other_cells_mg                         Source
# 0      116727          111754             Sarko et al., 2009
# 1       78672           68643  Herculano-Houzel et al., 2006
# 2       60214           80729             Sarko et al., 2009
# 3       33374           45894  Herculano-Houzel et al., 2011
# 4       40777           76995             Sarko et al., 2009

# %% [markdown]
# ## Once you have the data in Colab, you can work with it!

# %%
# Read as a dataframe
data = pd.read_csv(filepath)

# Show the first five rows of the dataframe
data.head(5)
